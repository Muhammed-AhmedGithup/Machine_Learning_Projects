# %%
import pandas as pd
import numpy as np
import requests as rq
import matplotlib.pyplot as plt

# %%
url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%202/data/FuelConsumptionCo2.csv'
res=rq.get(url)
with open('FuelConsumptionCo2.csv','wb') as f:
    f.write(res.content)

# %%
df=pd.read_csv('FuelConsumptionCo2.csv')
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
cdf = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267

# %%
viz = cdf[['CYLINDERS','ENGINESIZE','CO2EMISSIONS','FUELCONSUMPTION_COMB']]
viz.hist()
# Out:
# array([[<AxesSubplot:title={'center':'CYLINDERS'}>,
#         <AxesSubplot:title={'center':'ENGINESIZE'}>],
#        [<AxesSubplot:title={'center':'CO2EMISSIONS'}>,
#         <AxesSubplot:title={'center':'FUELCONSUMPTION_COMB'}>]],
#       dtype=object)

# %%
plt.scatter(cdf.CYLINDERS,cdf.CO2EMISSIONS)
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(cdf.ENGINESIZE, cdf.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
print(len(df))
# Out:
# 1067

# %%
msk=np.random.rand(len(df))<0.8
train=df[msk]
test=df[~msk]

# %%
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
train_x = np.asanyarray(train[['ENGINESIZE']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
lr.fit(train_x,train_y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[39.42548182]]
# [124.03594469]

# %%
plt.scatter(cdf.ENGINESIZE,cdf.CO2EMISSIONS)
plt.plot(train_x,train_x*lr.coef_[0][0]+lr.intercept_[0],'r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')

# %%
from sklearn.metrics import r2_score
test_x = np.asanyarray(test[['ENGINESIZE']])
test_y = np.asanyarray(test[['CO2EMISSIONS']])
yhat=lr.predict(test_x)

print(np.mean(np.absolute(yhat-test_y)))
print(np.mean((yhat-test_y)**2))
print(r2_score(test_y,yhat))
# Out:
# 23.96321580649976
# 971.0600049946422
# 0.7527284731688533

# %%
x=train[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']]
y=train['CO2EMISSIONS']
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [11.38289271  7.37768723  9.63973667]
# 63.92572860322079

# %%
yhat=lr.predict(test[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']])
print(np.mean((yhat-test['CO2EMISSIONS'])**2))
print(lr.score(x,y))
print(r2_score(test['CO2EMISSIONS'],yhat))
# Out:
# 561.7662916408632
# 0.8654705619313223
# 0.8569513645481939
